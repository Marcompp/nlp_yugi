# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("Hello World")
# Out:
# Hello World

# %%
df_yugi = pd.read_csv('dbs/yugioh_enriched.csv')

df_yugi.head
# Out:
# <bound method NDFrame.head of            id                      name            type  \
# 0     6983839            Tornado Dragon     XYZ Monster
# 1     6983839            Tornado Dragon     XYZ Monster
# 2     6983839            Tornado Dragon     XYZ Monster
# 3     6983839            Tornado Dragon     XYZ Monster
# 4    33396948  Exodia the Forbidden One  Effect Monster
# ..        ...                       ...             ...
# 790  10000020     Slifer the Sky Dragon  Effect Monster
# 791  10000020     Slifer the Sky Dragon  Effect Monster
# 792  10000020     Slifer the Sky Dragon  Effect Monster
# 793  10000020     Slifer the Sky Dragon  Effect Monster
# 794  10000020     Slifer the Sky Dragon  Effect Monster
#
#                                                   desc     atk     def  level  \
# 0    2 Level 4 monsters\nOnce per turn (Quick Effec...  2100.0  2000.0    4.0
# 1    2 Level 4 monsters\nOnce per turn (Quick Effec...  2100.0  2000.0    4.0
# 2    2 Level 4 monsters\nOnce per turn (Quick Effec...  2100.0  2000.0    4.0
# 3    2 Level 4 monsters\nOnce per turn (Quick Effec...  2100.0  2000.0    4.0
# 4    If you have "Right Leg of the Forbidden One", ...  1000.0  1000.0    3.0
# ..                                                 ...     ...     ...    ...
# 790  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
# 791  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
# 792  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
# 793  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
# 794  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
#
#              race attribute     archetype  ... card_sets_set_rarity_code  \
# 0            Wyrm      WIND           NaN  ...                     (ScR)
# 1            Wyrm      WIND           NaN  ...                      (UR)
# 2            Wyrm      WIND           NaN  ...                       (C)
# 3            Wyrm      WIND           NaN  ...                     (ScR)
# 4     Spellcaster      DARK        Exodia  ...                      (UR)
# ..            ...       ...           ...  ...                       ...
# 790  Divine-Beast    DIVINE  Egyptian God  ...                      (UR)
# 791  Divine-Beast    DIVINE  Egyptian God  ...                      (UR)
# 792  Divine-Beast    DIVINE  Egyptian God  ...                     (GUR)
# 793  Divine-Beast    DIVINE  Egyptian God  ...                     (GUR)
# 794  Divine-Beast    DIVINE  Egyptian God  ...                     (GUR)
#
#     card_sets_set_price card_images_id  \
# 0                  4.65        6983839
# 1                  1.58        6983839
# 2                  0.96        6983839
# 3                  4.49        6983839
# 4                 40.10       33396948
# ..                  ...            ...
# 790                3.97       10000021
# 791                3.97       10000022
# 792                3.48       10000020
# 793                3.48       10000021
# 794                3.48       10000022
#
#                                  card_images_image_url  \
# 0    https://images.ygoprodeck.com/images/cards/698...
# 1    https://images.ygoprodeck.com/images/cards/698...
# 2    https://images.ygoprodeck.com/images/cards/698...
# 3    https://images.ygoprodeck.com/images/cards/698...
# 4    https://images.ygoprodeck.com/images/cards/333...
# ..                                                 ...
# 790  https://images.ygoprodeck.com/images/cards/100...
# 791  https://images.ygoprodeck.com/images/cards/100...
# 792  https://images.ygoprodeck.com/images/cards/100...
# 793  https://images.ygoprodeck.com/images/cards/100...
# 794  https://images.ygoprodeck.com/images/cards/100...
#
#                            card_images_image_url_small  \
# 0    https://images.ygoprodeck.com/images/cards_sma...
# 1    https://images.ygoprodeck.com/images/cards_sma...
# 2    https://images.ygoprodeck.com/images/cards_sma...
# 3    https://images.ygoprodeck.com/images/cards_sma...
# 4    https://images.ygoprodeck.com/images/cards_sma...
# ..                                                 ...
# 790  https://images.ygoprodeck.com/images/cards_sma...
# 791  https://images.ygoprodeck.com/images/cards_sma...
# 792  https://images.ygoprodeck.com/images/cards_sma...
# 793  https://images.ygoprodeck.com/images/cards_sma...
# 794  https://images.ygoprodeck.com/images/cards_sma...
#
#     card_prices_cardmarket_price card_prices_tcgplayer_price  \
# 0                           0.19                        0.15
# 1                           0.19                        0.15
# 2                           0.19                        0.15
# 3                           0.19                        0.15
# 4                           0.46                        0.83
# ..                           ...                         ...
# 790                         1.07                        0.94
# 791                         1.07                        0.94
# 792                         1.07                        0.94
# 793                         1.07                        0.94
# 794                         1.07                        0.94
#
#      card_prices_ebay_price  card_prices_amazon_price  \
# 0                      1.90                      1.39
# 1                      1.90                      1.39
# 2                      1.90                      1.39
# 3                      1.90                      1.39
# 4                     24.98                      1.29
# ..                      ...                       ...
# 790                    3.95                      1.94
# 791                    3.95                      1.94
# 792                    3.95                      1.94
# 793                    3.95                      1.94
# 794                    3.95                      1.94
#
#     card_prices_coolstuffinc_price
# 0                             0.79
# 1                             0.79
# 2                             0.79
# 3                             0.79
# 4                            29.99
# ..                             ...
# 790                           2.99
# 791                           2.99
# 792                           2.99
# 793                           2.99
# 794                           2.99
#
# [795 rows x 26 columns]>

# %%
print(df_yugi.columns)
# Out:
# Index(['id', 'name', 'type', 'desc', 'atk', 'def', 'level', 'race',
#        'attribute', 'archetype', 'banlist_info.ban_tcg',
#        'banlist_info.ban_ocg', 'banlist_info.ban_goat', 'card_sets_set_name',
#        'card_sets_set_code', 'card_sets_set_rarity',
#        'card_sets_set_rarity_code', 'card_sets_set_price', 'card_images_id',
#        'card_images_image_url', 'card_images_image_url_small',
#        'card_prices_cardmarket_price', 'card_prices_tcgplayer_price',
#        'card_prices_ebay_price', 'card_prices_amazon_price',
#        'card_prices_coolstuffinc_price'],
#       dtype='object')

# %%
rarity = df_yugi['card_sets_set_rarity']

# %%
import matplotlib.pyplot as plt
import pandas as pd


sums = df_yugi['card_sets_set_rarity'].value_counts()
plt.axis('equal');
plt.pie(sums, labels=sums.index);
plt.show()

# %%
means = df_yugi.groupby(df_yugi['card_sets_set_rarity'])['card_prices_amazon_price'].mean().sort_values()
means
# Out:
# card_sets_set_rarity
# Ultra Parallel Rare                    0.790000
# Mosaic Rare                            2.622222
# Starfoil Rare                          4.050000
# Common                                 7.301230
# Super Rare                             7.863421
# Duel Terminal Normal Parallel Rare     7.950000
# Gold Rare                              8.273684
# Gold Secret Rare                       8.661667
# Rare                                   8.710000
# Prismatic Secret Rare                  9.941905
# Premium Gold Rare                     10.323846
# Secret Rare                           10.808778
# Ultra Rare                            11.021492
# Ultimate Rare                         13.623000
# Extra Secret Rare                     14.450000
# Ghost Rare                            14.450000
# Duel Terminal Rare Parallel Rare      14.450000
# Duel Terminal Ultra Parallel Rare     14.450000
# Name: card_prices_amazon_price, dtype: float64

# %%
means2 = df_yugi.groupby(df_yugi['card_sets_set_rarity'])['card_prices_tcgplayer_price'].mean().sort_values()
means2
# Out:
# card_sets_set_rarity
# Duel Terminal Normal Parallel Rare    0.325000
# Super Rare                            0.412632
# Ultra Parallel Rare                   0.440000
# Common                                0.465401
# Prismatic Secret Rare                 0.520000
# Duel Terminal Rare Parallel Rare      0.540000
# Duel Terminal Ultra Parallel Rare     0.540000
# Extra Secret Rare                     0.540000
# Ghost Rare                            0.540000
# Premium Gold Rare                     0.569231
# Ultra Rare                            0.576492
# Secret Rare                           0.618444
# Rare                                  0.637692
# Gold Secret Rare                      0.656667
# Gold Rare                             0.665789
# Ultimate Rare                         0.738000
# Mosaic Rare                           0.921111
# Starfoil Rare                         1.147500
# Name: card_prices_tcgplayer_price, dtype: float64

# %%
means3 = df_yugi.groupby(df_yugi['card_sets_set_rarity'])['card_prices_cardmarket_price'].mean().sort_values()
means3
# Out:
# card_sets_set_rarity
# Duel Terminal Rare Parallel Rare      0.020000
# Duel Terminal Ultra Parallel Rare     0.020000
# Extra Secret Rare                     0.020000
# Ghost Rare                            0.020000
# Ultra Parallel Rare                   0.020000
# Duel Terminal Normal Parallel Rare    0.035000
# Super Rare                            0.057368
# Common                                0.067914
# Premium Gold Rare                     0.087692
# Ultimate Rare                         0.117000
# Prismatic Secret Rare                 0.167619
# Rare                                  0.175385
# Ultra Rare                            0.183306
# Secret Rare                           0.220000
# Gold Rare                             0.464737
# Gold Secret Rare                      0.465000
# Mosaic Rare                           0.747778
# Starfoil Rare                         0.870000
# Name: card_prices_cardmarket_price, dtype: float64

# %%
means4 = df_yugi.groupby(df_yugi['card_sets_set_rarity'])['card_prices_amazon_price'].mean().sort_values()
means4
# Out:
# card_sets_set_rarity
# Ultra Parallel Rare                    0.790000
# Mosaic Rare                            2.622222
# Starfoil Rare                          4.050000
# Common                                 7.301230
# Super Rare                             7.863421
# Duel Terminal Normal Parallel Rare     7.950000
# Gold Rare                              8.273684
# Gold Secret Rare                       8.661667
# Rare                                   8.710000
# Prismatic Secret Rare                  9.941905
# Premium Gold Rare                     10.323846
# Secret Rare                           10.808778
# Ultra Rare                            11.021492
# Ultimate Rare                         13.623000
# Extra Secret Rare                     14.450000
# Ghost Rare                            14.450000
# Duel Terminal Rare Parallel Rare      14.450000
# Duel Terminal Ultra Parallel Rare     14.450000
# Name: card_prices_amazon_price, dtype: float64

# %%
means5 = df_yugi.groupby(df_yugi['card_sets_set_rarity'])['card_prices_coolstuffinc_price'].mean().sort_values()
means5
# Out:
# card_sets_set_rarity
# Ultra Parallel Rare                   0.990000
# Mosaic Rare                           2.323333
# Starfoil Rare                         2.490000
# Duel Terminal Normal Parallel Rare    2.690000
# Super Rare                            2.715789
# Common                                2.789893
# Gold Secret Rare                      3.656667
# Rare                                  3.832308
# Prismatic Secret Rare                 4.380476
# Ultimate Rare                         4.890000
# Extra Secret Rare                     4.990000
# Duel Terminal Ultra Parallel Rare     4.990000
# Duel Terminal Rare Parallel Rare      4.990000
# Ghost Rare                            4.990000
# Gold Rare                             5.042632
# Ultra Rare                            5.055323
# Secret Rare                           5.065556
# Premium Gold Rare                     8.220769
# Name: card_prices_coolstuffinc_price, dtype: float64

# %%
df_yugi['price'] = df_yugi[['card_prices_cardmarket_price','card_prices_tcgplayer_price','card_prices_ebay_price','card_prices_amazon_price', 'card_prices_coolstuffinc_price']].mean(axis=1)
df_yugi.head
# Out:
# <bound method NDFrame.head of            id                      name            type  \
# 0     6983839            Tornado Dragon     XYZ Monster
# 1     6983839            Tornado Dragon     XYZ Monster
# 2     6983839            Tornado Dragon     XYZ Monster
# 3     6983839            Tornado Dragon     XYZ Monster
# 4    33396948  Exodia the Forbidden One  Effect Monster
# ..        ...                       ...             ...
# 790  10000020     Slifer the Sky Dragon  Effect Monster
# 791  10000020     Slifer the Sky Dragon  Effect Monster
# 792  10000020     Slifer the Sky Dragon  Effect Monster
# 793  10000020     Slifer the Sky Dragon  Effect Monster
# 794  10000020     Slifer the Sky Dragon  Effect Monster
#
#                                                   desc     atk     def  level  \
# 0    2 Level 4 monsters\nOnce per turn (Quick Effec...  2100.0  2000.0    4.0
# 1    2 Level 4 monsters\nOnce per turn (Quick Effec...  2100.0  2000.0    4.0
# 2    2 Level 4 monsters\nOnce per turn (Quick Effec...  2100.0  2000.0    4.0
# 3    2 Level 4 monsters\nOnce per turn (Quick Effec...  2100.0  2000.0    4.0
# 4    If you have "Right Leg of the Forbidden One", ...  1000.0  1000.0    3.0
# ..                                                 ...     ...     ...    ...
# 790  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
# 791  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
# 792  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
# 793  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
# 794  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
#
#              race attribute     archetype  ... card_sets_set_price  \
# 0            Wyrm      WIND           NaN  ...                4.65
# 1            Wyrm      WIND           NaN  ...                1.58
# 2            Wyrm      WIND           NaN  ...                0.96
# 3            Wyrm      WIND           NaN  ...                4.49
# 4     Spellcaster      DARK        Exodia  ...               40.10
# ..            ...       ...           ...  ...                 ...
# 790  Divine-Beast    DIVINE  Egyptian God  ...                3.97
# 791  Divine-Beast    DIVINE  Egyptian God  ...                3.97
# 792  Divine-Beast    DIVINE  Egyptian God  ...                3.48
# 793  Divine-Beast    DIVINE  Egyptian God  ...                3.48
# 794  Divine-Beast    DIVINE  Egyptian God  ...                3.48
#
#     card_images_id                              card_images_image_url  \
# 0          6983839  https://images.ygoprodeck.com/images/cards/698...
# 1          6983839  https://images.ygoprodeck.com/images/cards/698...
# 2          6983839  https://images.ygoprodeck.com/images/cards/698...
# 3          6983839  https://images.ygoprodeck.com/images/cards/698...
# 4         33396948  https://images.ygoprodeck.com/images/cards/333...
# ..             ...                                                ...
# 790       10000021  https://images.ygoprodeck.com/images/cards/100...
# 791       10000022  https://images.ygoprodeck.com/images/cards/100...
# 792       10000020  https://images.ygoprodeck.com/images/cards/100...
# 793       10000021  https://images.ygoprodeck.com/images/cards/100...
# 794       10000022  https://images.ygoprodeck.com/images/cards/100...
#
#                            card_images_image_url_small  \
# 0    https://images.ygoprodeck.com/images/cards_sma...
# 1    https://images.ygoprodeck.com/images/cards_sma...
# 2    https://images.ygoprodeck.com/images/cards_sma...
# 3    https://images.ygoprodeck.com/images/cards_sma...
# 4    https://images.ygoprodeck.com/images/cards_sma...
# ..                                                 ...
# 790  https://images.ygoprodeck.com/images/cards_sma...
# 791  https://images.ygoprodeck.com/images/cards_sma...
# 792  https://images.ygoprodeck.com/images/cards_sma...
# 793  https://images.ygoprodeck.com/images/cards_sma...
# 794  https://images.ygoprodeck.com/images/cards_sma...
#
#     card_prices_cardmarket_price card_prices_tcgplayer_price  \
# 0                           0.19                        0.15
# 1                           0.19                        0.15
# 2                           0.19                        0.15
# 3                           0.19                        0.15
# 4                           0.46                        0.83
# ..                           ...                         ...
# 790                         1.07                        0.94
# 791                         1.07                        0.94
# 792                         1.07                        0.94
# 793                         1.07                        0.94
# 794                         1.07                        0.94
#
#     card_prices_ebay_price  card_prices_amazon_price  \
# 0                     1.90                      1.39
# 1                     1.90                      1.39
# 2                     1.90                      1.39
# 3                     1.90                      1.39
# 4                    24.98                      1.29
# ..                     ...                       ...
# 790                   3.95                      1.94
# 791                   3.95                      1.94
# 792                   3.95                      1.94
# 793                   3.95                      1.94
# 794                   3.95                      1.94
#
#      card_prices_coolstuffinc_price   price
# 0                              0.79   0.884
# 1                              0.79   0.884
# 2                              0.79   0.884
# 3                              0.79   0.884
# 4                             29.99  11.510
# ..                              ...     ...
# 790                            2.99   2.178
# 791                            2.99   2.178
# 792                            2.99   2.178
# 793                            2.99   2.178
# 794                            2.99   2.178
#
# [795 rows x 27 columns]>

# %%
meansp = df_yugi.groupby(df_yugi['card_sets_set_rarity'])['price'].mean().sort_values()
meansp
# Out:
# card_sets_set_rarity
# Ultra Parallel Rare                   1.238000
# Mosaic Rare                           1.979556
# Starfoil Rare                         2.201500
# Common                                3.822203
# Gold Secret Rare                      4.044667
# Super Rare                            4.076684
# Duel Terminal Normal Parallel Rare    4.294000
# Gold Rare                             4.437579
# Rare                                  4.524577
# Prismatic Secret Rare                 4.936143
# Secret Rare                           5.257244
# Ultra Rare                            5.307669
# Ultimate Rare                         5.923600
# Extra Secret Rare                     6.190000
# Ghost Rare                            6.190000
# Duel Terminal Rare Parallel Rare      6.190000
# Duel Terminal Ultra Parallel Rare     6.190000
# Premium Gold Rare                     6.246615
# Name: price, dtype: float64

# %%
#Sort by rarity
sorter = list(meansp.keys())
df_yugi.card_sets_set_rarity = df_yugi.card_sets_set_rarity.astype("category")
df_yugi.card_sets_set_rarity = df_yugi.card_sets_set_rarity.cat.set_categories(sorter)
df_yugi.sort_values(["card_sets_set_rarity"])
# Out:
#            id                      name            type  \
# 701  83764719            Monster Reborn      Spell Card
# 702  83764719            Monster Reborn      Spell Card
# 602  10000000     Obelisk the Tormentor  Effect Monster
# 600  10000000     Obelisk the Tormentor  Effect Monster
# 601  10000000     Obelisk the Tormentor  Effect Monster
# ..        ...                       ...             ...
# 721  83764719            Monster Reborn      Spell Card
# 249  46986421             Dark Magician  Normal Monster
# 246  46986421             Dark Magician  Normal Monster
# 248  46986421             Dark Magician  Normal Monster
# 13   33396948  Exodia the Forbidden One  Effect Monster
#
#                                                   desc     atk     def  level  \
# 701  Target 1 monster in either GY; Special Summon it.     NaN     NaN    NaN
# 702  Target 1 monster in either GY; Special Summon it.     NaN     NaN    NaN
# 602  Requires 3 Tributes to Normal Summon (cannot b...  4000.0  4000.0   10.0
# 600  Requires 3 Tributes to Normal Summon (cannot b...  4000.0  4000.0   10.0
# 601  Requires 3 Tributes to Normal Summon (cannot b...  4000.0  4000.0   10.0
# ..                                                 ...     ...     ...    ...
# 721  Target 1 monster in either GY; Special Summon it.     NaN     NaN    NaN
# 249  ''The ultimate wizard in terms of attack and d...  2500.0  2100.0    7.0
# 246  ''The ultimate wizard in terms of attack and d...  2500.0  2100.0    7.0
# 248  ''The ultimate wizard in terms of attack and d...  2500.0  2100.0    7.0
# 13   If you have "Right Leg of the Forbidden One", ...  1000.0  1000.0    3.0
#
#              race attribute      archetype  ... card_sets_set_price  \
# 701        Normal       NaN            NaN  ...               43.71
# 702        Normal       NaN            NaN  ...               43.71
# 602  Divine-Beast    DIVINE   Egyptian God  ...               15.34
# 600  Divine-Beast    DIVINE   Egyptian God  ...               15.34
# 601  Divine-Beast    DIVINE   Egyptian God  ...               15.34
# ..            ...       ...            ...  ...                 ...
# 721        Normal       NaN            NaN  ...                2.97
# 249   Spellcaster      DARK  Dark Magician  ...               11.91
# 246   Spellcaster      DARK  Dark Magician  ...               11.91
# 248   Spellcaster      DARK  Dark Magician  ...               11.91
# 13    Spellcaster      DARK         Exodia  ...                0.00
#
#     card_images_id                              card_images_image_url  \
# 701       83764719  https://images.ygoprodeck.com/images/cards/837...
# 702       83764718  https://images.ygoprodeck.com/images/cards/837...
# 602       10000002  https://images.ygoprodeck.com/images/cards/100...
# 600       10000000  https://images.ygoprodeck.com/images/cards/100...
# 601       10000001  https://images.ygoprodeck.com/images/cards/100...
# ..             ...                                                ...
# 721       83764719  https://images.ygoprodeck.com/images/cards/837...
# 249       46986415  https://images.ygoprodeck.com/images/cards/469...
# 246       46986421  https://images.ygoprodeck.com/images/cards/469...
# 248       46986414  https://images.ygoprodeck.com/images/cards/469...
# 13        33396948  https://images.ygoprodeck.com/images/cards/333...
#
#                            card_images_image_url_small  \
# 701  https://images.ygoprodeck.com/images/cards_sma...
# 702  https://images.ygoprodeck.com/images/cards_sma...
# 602  https://images.ygoprodeck.com/images/cards_sma...
# 600  https://images.ygoprodeck.com/images/cards_sma...
# 601  https://images.ygoprodeck.com/images/cards_sma...
# ..                                                 ...
# 721  https://images.ygoprodeck.com/images/cards_sma...
# 249  https://images.ygoprodeck.com/images/cards_sma...
# 246  https://images.ygoprodeck.com/images/cards_sma...
# 248  https://images.ygoprodeck.com/images/cards_sma...
# 13   https://images.ygoprodeck.com/images/cards_sma...
#
#     card_prices_cardmarket_price card_prices_tcgplayer_price  \
# 701                         0.02                        0.44
# 702                         0.02                        0.44
# 602                         0.83                        0.69
# 600                         0.83                        0.69
# 601                         0.83                        0.69
# ..                           ...                         ...
# 721                         0.02                        0.44
# 249                         0.02                        0.54
# 246                         0.02                        0.54
# 248                         0.02                        0.54
# 13                          0.46                        0.83
#
#     card_prices_ebay_price  card_prices_amazon_price  \
# 701                   3.95                      0.79
# 702                   3.95                      0.79
# 602                   1.95                      3.34
# 600                   1.95                      3.34
# 601                   1.95                      3.34
# ..                     ...                       ...
# 721                   3.95                      0.79
# 249                  10.95                     14.45
# 246                  10.95                     14.45
# 248                  10.95                     14.45
# 13                   24.98                      1.29
#
#      card_prices_coolstuffinc_price   price
# 701                            0.99   1.238
# 702                            0.99   1.238
# 602                            1.99   1.760
# 600                            1.99   1.760
# 601                            1.99   1.760
# ..                              ...     ...
# 721                            0.99   1.238
# 249                            4.99   6.190
# 246                            4.99   6.190
# 248                            4.99   6.190
# 13                            29.99  11.510
#
# [795 rows x 27 columns]

# %%
#Drop duplicates
df_yugioh = df_yugi.drop_duplicates(subset=["name"], keep="first")
df_yugioh.head
# Out:
# <bound method NDFrame.head of            id                      name            type  \
# 0     6983839            Tornado Dragon     XYZ Monster
# 4    33396948  Exodia the Forbidden One  Effect Monster
# 21   46986421             Dark Magician  Normal Monster
# 507  40640057                   Kuriboh  Effect Monster
# 594  10000000     Obelisk the Tormentor  Effect Monster
# 642  55144522              Pot of Greed      Spell Card
# 660  59197169                      Yami      Spell Card
# 667  15025844              Mystical Elf  Normal Monster
# 683  83764719            Monster Reborn      Spell Card
# 753  10000020     Slifer the Sky Dragon  Effect Monster
#
#                                                   desc     atk     def  level  \
# 0    2 Level 4 monsters\nOnce per turn (Quick Effec...  2100.0  2000.0    4.0
# 4    If you have "Right Leg of the Forbidden One", ...  1000.0  1000.0    3.0
# 21   ''The ultimate wizard in terms of attack and d...  2500.0  2100.0    7.0
# 507  During damage calculation, if your opponent's ...   300.0   200.0    1.0
# 594  Requires 3 Tributes to Normal Summon (cannot b...  4000.0  4000.0   10.0
# 642                                      Draw 2 cards.     NaN     NaN    NaN
# 660  All Fiend and Spellcaster monsters on the fiel...     NaN     NaN    NaN
# 667  A delicate elf that lacks offense, but has a t...   800.0  2000.0    4.0
# 683  Target 1 monster in either GY; Special Summon it.     NaN     NaN    NaN
# 753  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
#
#              race attribute      archetype  ... card_sets_set_price  \
# 0            Wyrm      WIND            NaN  ...                4.65
# 4     Spellcaster      DARK         Exodia  ...               40.10
# 21    Spellcaster      DARK  Dark Magician  ...                6.97
# 507         Fiend      DARK        Kuriboh  ...                1.37
# 594  Divine-Beast    DIVINE   Egyptian God  ...                3.87
# 642        Normal       NaN          Greed  ...                4.98
# 660         Field       NaN            NaN  ...                2.07
# 667   Spellcaster     LIGHT            NaN  ...                4.00
# 683        Normal       NaN            NaN  ...                4.44
# 753  Divine-Beast    DIVINE   Egyptian God  ...                5.47
#
#     card_images_id                              card_images_image_url  \
# 0          6983839  https://images.ygoprodeck.com/images/cards/698...
# 4         33396948  https://images.ygoprodeck.com/images/cards/333...
# 21        46986421  https://images.ygoprodeck.com/images/cards/469...
# 507       40640057  https://images.ygoprodeck.com/images/cards/406...
# 594       10000000  https://images.ygoprodeck.com/images/cards/100...
# 642       55144522  https://images.ygoprodeck.com/images/cards/551...
# 660       59197169  https://images.ygoprodeck.com/images/cards/591...
# 667       15025844  https://images.ygoprodeck.com/images/cards/150...
# 683       83764719  https://images.ygoprodeck.com/images/cards/837...
# 753       10000020  https://images.ygoprodeck.com/images/cards/100...
#
#                            card_images_image_url_small  \
# 0    https://images.ygoprodeck.com/images/cards_sma...
# 4    https://images.ygoprodeck.com/images/cards_sma...
# 21   https://images.ygoprodeck.com/images/cards_sma...
# 507  https://images.ygoprodeck.com/images/cards_sma...
# 594  https://images.ygoprodeck.com/images/cards_sma...
# 642  https://images.ygoprodeck.com/images/cards_sma...
# 660  https://images.ygoprodeck.com/images/cards_sma...
# 667  https://images.ygoprodeck.com/images/cards_sma...
# 683  https://images.ygoprodeck.com/images/cards_sma...
# 753  https://images.ygoprodeck.com/images/cards_sma...
#
#     card_prices_cardmarket_price card_prices_tcgplayer_price  \
# 0                           0.19                        0.15
# 4                           0.46                        0.83
# 21                          0.02                        0.54
# 507                         0.05                        0.11
# 594                         0.83                        0.69
# 642                         0.99                        2.52
# 660                         0.02                        0.30
# 667                         0.05                        0.12
# 683                         0.02                        0.44
# 753                         1.07                        0.94
#
#     card_prices_ebay_price  card_prices_amazon_price  \
# 0                     1.90                      1.39
# 4                    24.98                      1.29
# 21                   10.95                     14.45
# 507                   9.99                      1.45
# 594                   1.95                      3.34
# 642                   3.95                      6.18
# 660                   3.99                      1.50
# 667                   5.99                      3.99
# 683                   3.95                      0.79
# 753                   3.95                      1.94
#
#      card_prices_coolstuffinc_price   price
# 0                              0.79   0.884
# 4                             29.99  11.510
# 21                             4.99   6.190
# 507                            0.39   2.398
# 594                            1.99   1.760
# 642                            3.99   3.526
# 660                            0.39   1.240
# 667                            0.25   2.080
# 683                            0.99   1.238
# 753                            2.99   2.178
#
# [10 rows x 27 columns]>

# %%
df_cleaned = df_yugioh.drop(['card_sets_set_rarity_code','card_images_id','card_images_image_url', 'card_images_image_url_small'], axis=1)
df_cleaned = df_cleaned.drop(['card_prices_cardmarket_price','card_prices_tcgplayer_price','card_prices_ebay_price','card_prices_amazon_price', 'card_prices_coolstuffinc_price'], axis=1)
df_cleaned.head
# Out:
# <bound method NDFrame.head of            id                      name            type  \
# 0     6983839            Tornado Dragon     XYZ Monster
# 4    33396948  Exodia the Forbidden One  Effect Monster
# 21   46986421             Dark Magician  Normal Monster
# 507  40640057                   Kuriboh  Effect Monster
# 594  10000000     Obelisk the Tormentor  Effect Monster
# 642  55144522              Pot of Greed      Spell Card
# 660  59197169                      Yami      Spell Card
# 667  15025844              Mystical Elf  Normal Monster
# 683  83764719            Monster Reborn      Spell Card
# 753  10000020     Slifer the Sky Dragon  Effect Monster
#
#                                                   desc     atk     def  level  \
# 0    2 Level 4 monsters\nOnce per turn (Quick Effec...  2100.0  2000.0    4.0
# 4    If you have "Right Leg of the Forbidden One", ...  1000.0  1000.0    3.0
# 21   ''The ultimate wizard in terms of attack and d...  2500.0  2100.0    7.0
# 507  During damage calculation, if your opponent's ...   300.0   200.0    1.0
# 594  Requires 3 Tributes to Normal Summon (cannot b...  4000.0  4000.0   10.0
# 642                                      Draw 2 cards.     NaN     NaN    NaN
# 660  All Fiend and Spellcaster monsters on the fiel...     NaN     NaN    NaN
# 667  A delicate elf that lacks offense, but has a t...   800.0  2000.0    4.0
# 683  Target 1 monster in either GY; Special Summon it.     NaN     NaN    NaN
# 753  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
#
#              race attribute      archetype banlist_info.ban_tcg  \
# 0            Wyrm      WIND            NaN                  NaN
# 4     Spellcaster      DARK         Exodia              Limited
# 21    Spellcaster      DARK  Dark Magician                  NaN
# 507         Fiend      DARK        Kuriboh                  NaN
# 594  Divine-Beast    DIVINE   Egyptian God                  NaN
# 642        Normal       NaN          Greed               Banned
# 660         Field       NaN            NaN                  NaN
# 667   Spellcaster     LIGHT            NaN                  NaN
# 683        Normal       NaN            NaN              Limited
# 753  Divine-Beast    DIVINE   Egyptian God                  NaN
#
#     banlist_info.ban_ocg banlist_info.ban_goat  \
# 0                    NaN                   NaN
# 4                Limited               Limited
# 21                   NaN                   NaN
# 507                  NaN                   NaN
# 594                  NaN                   NaN
# 642               Banned               Limited
# 660                  NaN                   NaN
# 667                  NaN                   NaN
# 683              Limited                Banned
# 753                  NaN                   NaN
#
#                         card_sets_set_name card_sets_set_code  \
# 0    Battles of Legend: Relentless Revenge         BLRR-EN084
# 4                         Dark Beginning 1          DB1-EN139
# 21                          2016 Mega-Tins         CT13-EN003
# 507                     Brothers of Legend         BROL-EN062
# 594                         2016 Mega-Tins         CT13-EN002
# 642       Battle Pack 2: War of the Giants         BP02-EN129
# 660       Legend of Blue Eyes White Dragon            LOB-051
# 667   2-Player Starter Deck: Yuya & Declan         YS15-ENY02
# 683              2019 Gold Sarcophagus Tin         TN19-EN011
# 753                         2016 Mega-Tins         CT13-EN001
#
#       card_sets_set_rarity  card_sets_set_price   price
# 0              Secret Rare                 4.65   0.884
# 4               Ultra Rare                40.10  11.510
# 21              Ultra Rare                 6.97   6.190
# 507             Ultra Rare                 1.37   2.398
# 594            Secret Rare                 3.87   1.760
# 642            Mosaic Rare                 4.98   3.526
# 660                 Common                 2.07   1.240
# 667                 Common                 4.00   2.080
# 683  Prismatic Secret Rare                 4.44   1.238
# 753            Secret Rare                 5.47   2.178  >

# %%
means['Common']
# Out:
# 7.301229946524064

# %%
def judgeQuality(row):  
    mprice = meansp[row['card_sets_set_rarity']]
    return (row['price'] > mprice)

# %%
df_cleaned['isGood'] = df_cleaned.apply(lambda row: judgeQuality(row), axis=1)
df_cleaned.head
# Out:
# <bound method NDFrame.head of            id                      name            type  \
# 0     6983839            Tornado Dragon     XYZ Monster
# 4    33396948  Exodia the Forbidden One  Effect Monster
# 21   46986421             Dark Magician  Normal Monster
# 507  40640057                   Kuriboh  Effect Monster
# 594  10000000     Obelisk the Tormentor  Effect Monster
# 642  55144522              Pot of Greed      Spell Card
# 660  59197169                      Yami      Spell Card
# 667  15025844              Mystical Elf  Normal Monster
# 683  83764719            Monster Reborn      Spell Card
# 753  10000020     Slifer the Sky Dragon  Effect Monster
#
#                                                   desc     atk     def  level  \
# 0    2 Level 4 monsters\nOnce per turn (Quick Effec...  2100.0  2000.0    4.0
# 4    If you have "Right Leg of the Forbidden One", ...  1000.0  1000.0    3.0
# 21   ''The ultimate wizard in terms of attack and d...  2500.0  2100.0    7.0
# 507  During damage calculation, if your opponent's ...   300.0   200.0    1.0
# 594  Requires 3 Tributes to Normal Summon (cannot b...  4000.0  4000.0   10.0
# 642                                      Draw 2 cards.     NaN     NaN    NaN
# 660  All Fiend and Spellcaster monsters on the fiel...     NaN     NaN    NaN
# 667  A delicate elf that lacks offense, but has a t...   800.0  2000.0    4.0
# 683  Target 1 monster in either GY; Special Summon it.     NaN     NaN    NaN
# 753  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
#
#              race attribute      archetype banlist_info.ban_tcg  \
# 0            Wyrm      WIND            NaN                  NaN
# 4     Spellcaster      DARK         Exodia              Limited
# 21    Spellcaster      DARK  Dark Magician                  NaN
# 507         Fiend      DARK        Kuriboh                  NaN
# 594  Divine-Beast    DIVINE   Egyptian God                  NaN
# 642        Normal       NaN          Greed               Banned
# 660         Field       NaN            NaN                  NaN
# 667   Spellcaster     LIGHT            NaN                  NaN
# 683        Normal       NaN            NaN              Limited
# 753  Divine-Beast    DIVINE   Egyptian God                  NaN
#
#     banlist_info.ban_ocg banlist_info.ban_goat  \
# 0                    NaN                   NaN
# 4                Limited               Limited
# 21                   NaN                   NaN
# 507                  NaN                   NaN
# 594                  NaN                   NaN
# 642               Banned               Limited
# 660                  NaN                   NaN
# 667                  NaN                   NaN
# 683              Limited                Banned
# 753                  NaN                   NaN
#
#                         card_sets_set_name card_sets_set_code  \
# 0    Battles of Legend: Relentless Revenge         BLRR-EN084
# 4                         Dark Beginning 1          DB1-EN139
# 21                          2016 Mega-Tins         CT13-EN003
# 507                     Brothers of Legend         BROL-EN062
# 594                         2016 Mega-Tins         CT13-EN002
# 642       Battle Pack 2: War of the Giants         BP02-EN129
# 660       Legend of Blue Eyes White Dragon            LOB-051
# 667   2-Player Starter Deck: Yuya & Declan         YS15-ENY02
# 683              2019 Gold Sarcophagus Tin         TN19-EN011
# 753                         2016 Mega-Tins         CT13-EN001
#
#       card_sets_set_rarity  card_sets_set_price   price  isGood
# 0              Secret Rare                 4.65   0.884   False
# 4               Ultra Rare                40.10  11.510    True
# 21              Ultra Rare                 6.97   6.190    True
# 507             Ultra Rare                 1.37   2.398   False
# 594            Secret Rare                 3.87   1.760   False
# 642            Mosaic Rare                 4.98   3.526    True
# 660                 Common                 2.07   1.240   False
# 667                 Common                 4.00   2.080   False
# 683  Prismatic Secret Rare                 4.44   1.238   False
# 753            Secret Rare                 5.47   2.178   False  >

# %% [markdown]
# ## TFIDF

# %%
dfg = df_cleaned.query("isGood")
dfb = df_cleaned.query("not isGood")
dfb.head
# Out:
# <bound method NDFrame.head of            id                   name            type  \
# 0     6983839         Tornado Dragon     XYZ Monster
# 507  40640057                Kuriboh  Effect Monster
# 594  10000000  Obelisk the Tormentor  Effect Monster
# 660  59197169                   Yami      Spell Card
# 667  15025844           Mystical Elf  Normal Monster
# 683  83764719         Monster Reborn      Spell Card
# 753  10000020  Slifer the Sky Dragon  Effect Monster
#
#                                                   desc     atk     def  level  \
# 0    2 Level 4 monsters\nOnce per turn (Quick Effec...  2100.0  2000.0    4.0
# 507  During damage calculation, if your opponent's ...   300.0   200.0    1.0
# 594  Requires 3 Tributes to Normal Summon (cannot b...  4000.0  4000.0   10.0
# 660  All Fiend and Spellcaster monsters on the fiel...     NaN     NaN    NaN
# 667  A delicate elf that lacks offense, but has a t...   800.0  2000.0    4.0
# 683  Target 1 monster in either GY; Special Summon it.     NaN     NaN    NaN
# 753  Requires 3 Tributes to Normal Summon (cannot b...     0.0     0.0   10.0
#
#              race attribute     archetype banlist_info.ban_tcg  \
# 0            Wyrm      WIND           NaN                  NaN
# 507         Fiend      DARK       Kuriboh                  NaN
# 594  Divine-Beast    DIVINE  Egyptian God                  NaN
# 660         Field       NaN           NaN                  NaN
# 667   Spellcaster     LIGHT           NaN                  NaN
# 683        Normal       NaN           NaN              Limited
# 753  Divine-Beast    DIVINE  Egyptian God                  NaN
#
#     banlist_info.ban_ocg banlist_info.ban_goat  \
# 0                    NaN                   NaN
# 507                  NaN                   NaN
# 594                  NaN                   NaN
# 660                  NaN                   NaN
# 667                  NaN                   NaN
# 683              Limited                Banned
# 753                  NaN                   NaN
#
#                         card_sets_set_name card_sets_set_code  \
# 0    Battles of Legend: Relentless Revenge         BLRR-EN084
# 507                     Brothers of Legend         BROL-EN062
# 594                         2016 Mega-Tins         CT13-EN002
# 660       Legend of Blue Eyes White Dragon            LOB-051
# 667   2-Player Starter Deck: Yuya & Declan         YS15-ENY02
# 683              2019 Gold Sarcophagus Tin         TN19-EN011
# 753                         2016 Mega-Tins         CT13-EN001
#
#       card_sets_set_rarity  card_sets_set_price  price  isGood
# 0              Secret Rare                 4.65  0.884   False
# 507             Ultra Rare                 1.37  2.398   False
# 594            Secret Rare                 3.87  1.760   False
# 660                 Common                 2.07  1.240   False
# 667                 Common                 4.00  2.080   False
# 683  Prismatic Secret Rare                 4.44  1.238   False
# 753            Secret Rare                 5.47  2.178   False  >

# %%
def get_term(dict, search_index):
    return list(dict.keys())[list(dict.values()).index(search_index)]

# %%
def word_frequencies(tfidf):
    tfidfadd = []
    words = []
    for j in range(tfidf.shape[1]):
        words.append(get_term(vectorizer.vocabulary_,j))
        tfidfadd.append(0)
        for i in range(tfidf.shape[0]):            
            tfidfadd[j] += tfidf[i, j]
    return tfidfadd, words

# %%
import operator
import heapq


def get_top_words(n,tfidf):
    tfdfadd, words = word_frequencies(tfidf)
    return get_top(n,tfdfadd,words)

def get_top(n,tfidfadd,words):
    #stopwords = ["the"]
    #sw = []
    #for stopword in stopwords:
    #    sw.append(words.index(stopword))
    

    tops = list(list(zip(*heapq.nlargest(n, enumerate(tfidfadd), key=operator.itemgetter(1))))[0])
    print(tops)
    
    for word in list(tops):  # iterating on a copy since removing will mess things up
        if word in sw:
            tops.remove(word)
            print(tops)
    res = 0
    while (len(tops) < n):
        res += n - len(tops)
        tops = list(list(zip(*heapq.nlargest(n+res, enumerate(tfidfadd), key=operator.itemgetter(1))))[0])
        for word in list(tops):
            if word in sw:
                tops.remove(word)
        
    
    values = []
    labels = []
    tot = 0
    
    for j in tops:
        values.append(tfidfadd[j]/len(tfidfadd))
        labels.append(words[j])

    for j in range(len(tfidfadd)):
        if j in tops:
            values.append(tfidfadd[j]/len(tfidfadd))
            labels.append(words[j])
        else:
            tot += tfidfadd[j]/len(tfidfadd)
    #values.append(tot)
    #labels.append("Other")
    return values, labels

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from pprint import pprint

vectorizer = TfidfVectorizer()

# Compute the TF-IDF matrix
tfidf_g = vectorizer.fit_transform(dfg["desc"])

# %%
tfidf_b = vectorizer.fit_transform(dfb["desc"])

# %%
tfdfadd_g, words = word_frequencies(tfidf_g)
print("foi")
# Out:
# foi

# %%
tfdfadd_b, words = word_frequencies(tfidf_b)
print("foi")
# Out:
# foi

# %%
values, labels = get_top(30,tfdfadd_g,words)

#fig, ax = plt.subplots()
plt.title("Most frequent words / Good")
plt.xticks(rotation='vertical')
plt.bar(labels,values)
# Out:
# [5, 7, 20, 16, 13, 9, 17, 3, 6, 19, 23, 25, 1, 2, 14, 15, 18, 26, 0, 4, 8, 10, 11, 12, 21, 22, 24, 27]

# %%
values, labels = get_top(30,tfdfadd_b,words)

#fig, ax = plt.subplots()
plt.title("Most frequent words / Bad")
plt.xticks(rotation='vertical')
plt.bar(labels,values)
